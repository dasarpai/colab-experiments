# %% [markdown]
# # PRefLexOR Inference: Thinking and Agentic Reflection

# %%
# !pip install git+https://github.com/lamm-mit/PRefLexOR.git --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 71.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 790.2/790.2 kB 47.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 25.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 36.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.7/300.7 kB 26.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 59.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 20.7 MB/s eta 0:00:00
#   Building wheel for PRefLexOR (setup.py) ... done

# %%
import os

from tqdm.notebook import tqdm
from transformers import AutoModelForCausalLM, AutoTokenizer

import torch

from PRefLexOR import *

# Define thinking tokens
think_start = '<|thinking|>'
think_end = '<|/thinking|>'
import transformers

# %% [markdown]
# ### Load model

# %%
model_name='lamm-mit/PRefLexOR_ORPO_DPO_EXO_10242024'

model = AutoModelForCausalLM.from_pretrained(model_name,
    torch_dtype =torch.bfloat16,
    #attn_implementation="flash_attention_2",
    device_map="auto", trust_remote_code=True,
    )
tokenizer = AutoTokenizer.from_pretrained(model_name, )
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/935 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/21.0k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.25G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/54.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]

# %% [markdown]
# ### Inference: Conventional

# %%
txt = 'What is the relationship between materials and music? Brief answer.' + f' Use {think_start}.'

output_text, messages = generate_local_model(
    model=model,
    tokenizer=tokenizer,
    prompt=txt,
    system_prompt='',
    num_return_sequences=1,
    repetition_penalty=1.0,
    temperature=0.1,
    max_new_tokens=2024,
    messages=[],
    do_sample=True
)

print(output_text)
# Out:
# <|thinking|>
# **Reasoning Steps**:
#
# Materials and music share a common thread through their intrinsic properties and behaviors, which are fundamental to both. This relationship is rooted in the physical and chemical characteristics of materials, such as their structure, composition, and interactions, which influence their acoustic properties and the way they respond to sound waves. This, in turn, affects the perception and creation of music. Materials can be engineered to produce specific sounds, enhance musical expression, and even create new musical instruments. The relationship between materials and music is thus deeply intertwined, with materials serving as the physical foundation for the creation and manipulation of sound, and music being the expressive and aesthetic outcome of these interactions.
#
# **Relevant Materials or Concepts**:
#
# The relationship between materials and music is rooted in the intrinsic properties and behaviors of materials, which influence their acoustic properties and the way they respond to sound waves. This relationship is fundamental to both materials science and music, as materials can be engineered to produce specific sounds, enhance musical expression, and create new musical instruments.
#
# **Design Principles**:
#
# The relationship between materials and music is rooted in the intrinsic properties and behaviors of materials, which influence their acoustic properties and the way they respond to sound waves. This relationship is fundamental to both materials science and music, as materials can be engineered to produce specific sounds, enhance musical expression, and create new musical instruments.
#
# **Material Properties Relevant to the Question**:
#
# The relevant material properties for the relationship between materials and music are:
#
# 1. **Structural Hierarchy**: Materials with complex hierarchical structures can exhibit unique acoustic properties, such as tunability and self-similarity, which are crucial for musical applications.
# 2. **An
# 3. **Anisotropic Properties**: Materials with anisotropic properties can produce distinct sound patterns when struck or vibrated, contributing to the diversity of musical sounds.
# 4. **Viscoelasticity**: Materials with viscoelastic properties can exhibit dynamic behavior, such as resonance and damping, which can be exploited for musical purposes.
# 5. **Surface Properties**: The surface properties of materials, such as roughness and texture, can influence sound wave propagation and absorption, affecting the overall sound quality and musical expression.
# 6. **Chemical Composition**: The chemical composition of materials can influence their acoustic properties, such as density and specific gravity, which can be manipulated to create specific sounds.
# 7. **Microstructural Properties**: The microstructural properties of materials, such as porosity and inclusions, can affect their acoustic properties and the way they respond to sound waves.
#
# **Hypothesis**:
#
# "Materials' intrinsic properties and behaviors, influenced by their structure, composition, and interactions, shape the acoustic properties and sound wave propagation, which in turn affect the perception and creation of music."
#
# **Additional Background**:
#
# The relationship between materials and music is deeply rooted in the physical and chemical properties of materials, which influence their acoustic properties and the way they respond to sound waves. Materials can be engineered to produce specific sounds, enhance musical expression, and create new instruments. The structure and composition of materials, such as porosity and inclusions, can affect their acoustic properties, while the surface properties, like roughness and texture, can influence sound wave propagation and absorption. The intrinsic properties of materials, like their viscoelasticity and anisotropy, also play a role in shaping the sound produced. This relationship is fundamental to both materials science and music, as it allows for the creation of new sounds and instruments, and the manipulation of existing ones.
#
# <|/thinking|>
# The relationship between materials and music is multifaceted and deeply rooted in the intrinsic properties and behaviors of materials, which influence their acoustic properties and the way they respond to sound waves. This relationship is fundamental to both materials science and music, as it allows for the creation of new sounds, instruments, and the manipulation of existing ones. Here's a comprehensive breakdown:
#
# 1. **Structural Hierarchy**: Materials with complex hierarchical structures can exhibit unique acoustic properties, such as tunability and self-similarity, which are crucial for musical applications. This is evident in materials like bone, which has a hierarchical structure that produces a distinct sound when struck.
#
# 2. **Anisotropic Properties**: Materials with anisotropic properties can produce distinct sound patterns when struck or vibrated, contributing to the diversity of musical sounds. This is seen in materials like bone, which has anisotropic properties that produce a unique sound.
#
# 3. **Viscoelasticity**: Materials with viscoelastic properties can exhibit dynamic behavior, such as resonance and damping, which can be exploited for musical purposes. This is evident in materials like bone, which has viscoelastic properties that produce a distinct sound when struck.
#
# 4. **Surface Properties**: The surface properties of materials, such as roughness and texture, can influence sound wave propagation and absorption, affecting the overall sound quality and musical expression. This is seen in materials like bone, which has a rough surface that produces a distinct sound.
#
# 5. **Chemical Composition**: The chemical composition of materials can influence their acoustic properties, such as density and specific gravity, which can be manipulated to create specific sounds. This is evident in materials like bone, which has a high density and specific gravity that produce a distinct sound.
#
# 6. **Microstructural Properties**: The microstructural properties of materials, such as porosity and inclusions, can affect their acoustic properties and the way they respond to sound waves. This is seen in materials like bone, which has a porous structure that produces a unique sound.
#
# 7. **Mechanical Properties**: The mechanical properties of materials, such as stiffness and strength, can influence their acoustic properties and the way they respond to sound waves. This is evident in materials like bone, which has a high stiffness and strength that produce a distinct sound.
#
# 8. **Thermal Properties**: The thermal properties of materials, such as thermal conductivity and thermal expansion, can influence their acoustic properties and the way they respond to sound waves. This is seen in materials like bone, which has a high thermal conductivity that produces a distinct sound.
#
# 9. **Electrical Properties**: The electrical properties of materials, such as electrical conductivity and electrical permittivity, can influence their acoustic properties and the way they respond to sound waves. This is evident in materials like bone, which has a high electrical conductivity that produces a distinct sound.
#
# 10. **Optical Properties**: The optical properties of materials, such as refractive and reflectivity, can influence their acoustic properties and the way they respond to sound waves. This is seen in materials like bone, which has a high refractive that produces a distinct sound.
#
# In conclusion, the relationship between materials and music is complex and multifaceted, with materials influencing acoustic properties and sound wave propagation, and music shaping the perception and creation of sound. This relationship is fundamental to both materials science and music, allowing for the creation of new sounds, instruments, and the manipulation of existing ones.

# %% [markdown]
# #### Extract thinking or other sections from the output

# %%
thinking    = extract_text(output_text, thinking_start=think_start, thinking_end=think_end)[0].strip()
answer_only = extract_text(output_text, thinking_start=think_end, thinking_end="NONE").strip()

# %%
print ("THINKING:\n\n", thinking)
# Out:
# THINKING:
#
#  **Reasoning Steps**:
#
# Materials and music share a common thread through their intrinsic properties and behaviors, which are fundamental to both. This relationship is rooted in the physical and chemical characteristics of materials, such as their structure, composition, and interactions, which influence their acoustic properties and the way they respond to sound waves. This, in turn, affects the perception and creation of music. Materials can be engineered to produce specific sounds, enhance musical expression, and even create new musical instruments. The relationship between materials and music is thus deeply intertwined, with materials serving as the physical foundation for the creation and manipulation of sound, and music being the expressive and aesthetic outcome of these interactions.
#
# **Relevant Materials or Concepts**:
#
# The relationship between materials and music is rooted in the intrinsic properties and behaviors of materials, which influence their acoustic properties and the way they respond to sound waves. This relationship is fundamental to both materials science and music, as materials can be engineered to produce specific sounds, enhance musical expression, and create new musical instruments.
#
# **Design Principles**:
#
# The relationship between materials and music is rooted in the intrinsic properties and behaviors of materials, which influence their acoustic properties and the way they respond to sound waves. This relationship is fundamental to both materials science and music, as materials can be engineered to produce specific sounds, enhance musical expression, and create new musical instruments.
#
# **Material Properties Relevant to the Question**:
#
# The relevant material properties for the relationship between materials and music are:
#
# 1. **Structural Hierarchy**: Materials with complex hierarchical structures can exhibit unique acoustic properties, such as tunability and self-similarity, which are crucial for musical applications.
# 2. **An
# 3. **Anisotropic Properties**: Materials with anisotropic properties can produce distinct sound patterns when struck or vibrated, contributing to the diversity of musical sounds.
# 4. **Viscoelasticity**: Materials with viscoelastic properties can exhibit dynamic behavior, such as resonance and damping, which can be exploited for musical purposes.
# 5. **Surface Properties**: The surface properties of materials, such as roughness and texture, can influence sound wave propagation and absorption, affecting the overall sound quality and musical expression.
# 6. **Chemical Composition**: The chemical composition of materials can influence their acoustic properties, such as density and specific gravity, which can be manipulated to create specific sounds.
# 7. **Microstructural Properties**: The microstructural properties of materials, such as porosity and inclusions, can affect their acoustic properties and the way they respond to sound waves.
#
# **Hypothesis**:
#
# "Materials' intrinsic properties and behaviors, influenced by their structure, composition, and interactions, shape the acoustic properties and sound wave propagation, which in turn affect the perception and creation of music."
#
# **Additional Background**:
#
# The relationship between materials and music is deeply rooted in the physical and chemical properties of materials, which influence their acoustic properties and the way they respond to sound waves. Materials can be engineered to produce specific sounds, enhance musical expression, and create new instruments. The structure and composition of materials, such as porosity and inclusions, can affect their acoustic properties, while the surface properties, like roughness and texture, can influence sound wave propagation and absorption. The intrinsic properties of materials, like their viscoelasticity and anisotropy, also play a role in shaping the sound produced. This relationship is fundamental to both materials science and music, as it allows for the creation of new sounds and instruments, and the manipulation of existing ones.

# %%
print ("ANSWER:\n\n", answer_only)
# Out:
# ANSWER:
#
#  The relationship between materials and music is multifaceted and deeply rooted in the intrinsic properties and behaviors of materials, which influence their acoustic properties and the way they respond to sound waves. This relationship is fundamental to both materials science and music, as it allows for the creation of new sounds, instruments, and the manipulation of existing ones. Here's a comprehensive breakdown:
#
# 1. **Structural Hierarchy**: Materials with complex hierarchical structures can exhibit unique acoustic properties, such as tunability and self-similarity, which are crucial for musical applications. This is evident in materials like bone, which has a hierarchical structure that produces a distinct sound when struck.
#
# 2. **Anisotropic Properties**: Materials with anisotropic properties can produce distinct sound patterns when struck or vibrated, contributing to the diversity of musical sounds. This is seen in materials like bone, which has anisotropic properties that produce a unique sound.
#
# 3. **Viscoelasticity**: Materials with viscoelastic properties can exhibit dynamic behavior, such as resonance and damping, which can be exploited for musical purposes. This is evident in materials like bone, which has viscoelastic properties that produce a distinct sound when struck.
#
# 4. **Surface Properties**: The surface properties of materials, such as roughness and texture, can influence sound wave propagation and absorption, affecting the overall sound quality and musical expression. This is seen in materials like bone, which has a rough surface that produces a distinct sound.
#
# 5. **Chemical Composition**: The chemical composition of materials can influence their acoustic properties, such as density and specific gravity, which can be manipulated to create specific sounds. This is evident in materials like bone, which has a high density and specific gravity that produce a distinct sound.
#
# 6. **Microstructural Properties**: The microstructural properties of materials, such as porosity and inclusions, can affect their acoustic properties and the way they respond to sound waves. This is seen in materials like bone, which has a porous structure that produces a unique sound.
#
# 7. **Mechanical Properties**: The mechanical properties of materials, such as stiffness and strength, can influence their acoustic properties and the way they respond to sound waves. This is evident in materials like bone, which has a high stiffness and strength that produce a distinct sound.
#
# 8. **Thermal Properties**: The thermal properties of materials, such as thermal conductivity and thermal expansion, can influence their acoustic properties and the way they respond to sound waves. This is seen in materials like bone, which has a high thermal conductivity that produces a distinct sound.
#
# 9. **Electrical Properties**: The electrical properties of materials, such as electrical conductivity and electrical permittivity, can influence their acoustic properties and the way they respond to sound waves. This is evident in materials like bone, which has a high electrical conductivity that produces a distinct sound.
#
# 10. **Optical Properties**: The optical properties of materials, such as refractive and reflectivity, can influence their acoustic properties and the way they respond to sound waves. This is seen in materials like bone, which has a high refractive that produces a distinct sound.
#
# In conclusion, the relationship between materials and music is complex and multifaceted, with materials influencing acoustic properties and sound wave propagation, and music shaping the perception and creation of sound. This relationship is fundamental to both materials science and music, allowing for the creation of new sounds, instruments, and the manipulation of existing ones.

# %% [markdown]
# ### Inference: Recursive using multi-agent reasoning

# %%
from PRefLexOR import recursive_response_from_thinking

# %% [markdown]
# #### Load second model that will be the critic agent

# %%
model_name_base = "meta-llama/Llama-3.2-3B-Instruct"

critic_model = AutoModelForCausalLM.from_pretrained(
    model_name_base,
    torch_dtype=torch.bfloat16,
    #attn_implementation="flash_attention_2",
    device_map="auto",
    trust_remote_code=True
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     405     try:
# --> 406         response.raise_for_status()
#     407     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     402         # Load from URL or cache if already cached
# --> 403         resolved_file = hf_hub_download(
#     404             path_or_repo_id,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     859     else:
# --> 860         return _hf_hub_download_to_cache_dir(
#     861             # Destination
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#     966         # Otherwise, raise appropriate error
# --> 967         _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#     968
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1481         # Repo not found or gated => let's raise the actual error
# -> 1482         raise head_call_error
#    1483     else:
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1373             try:
# -> 1374                 metadata = get_hf_file_metadata(
#    1375                     url=url, proxies=proxies, timeout=etag_timeout, headers=headers, token=token
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers)
#    1293     # Retrieve metadata
# -> 1294     r = _request_wrapper(
#    1295         method="HEAD",
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in _request_wrapper(method, url, follow_relative_redirects, **params)
#     277     if follow_relative_redirects:
# --> 278         response = _request_wrapper(
#     279             method=method,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in _request_wrapper(method, url, follow_relative_redirects, **params)
#     301     response = get_session().request(method=method, url=url, **params)
# --> 302     hf_raise_for_status(response)
#     303     return response
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     422             )
# --> 423             raise _format(GatedRepoError, message, response) from e
#     424
#
# GatedRepoError: 401 Client Error. (Request ID: Root=1-67bef4e6-2cbf5d455f2e96c52ca9860f;2fe10bf5-d05e-49d5-9fc6-d8459a4f2d99)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct/resolve/main/config.json.
# Access to model meta-llama/Llama-3.2-3B-Instruct is restricted. You must have access to it and be authenticated to access it. Please log in.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-14-b1a52fcf5b76> in <cell line: 0>()
#       1 model_name_base = "meta-llama/Llama-3.2-3B-Instruct"
#       2
# ----> 3 critic_model = AutoModelForCausalLM.from_pretrained(
#       4     model_name_base,
#       5     torch_dtype=torch.bfloat16,
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     524                 _ = kwargs.pop("quantization_config")
#     525
# --> 526             config, kwargs = AutoConfig.from_pretrained(
#     527                 pretrained_model_name_or_path,
#     528                 return_unused_kwargs=True,
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1052         code_revision = kwargs.pop("code_revision", None)
#    1053
# -> 1054         config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#    1055         has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#    1056         has_local_code = "model_type" in config_dict and config_dict["model_type"] in CONFIG_MAPPING
#
# /usr/local/lib/python3.11/dist-packages/transformers/configuration_utils.py in get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     589         original_kwargs = copy.deepcopy(kwargs)
#     590         # Get config dict associated with the base config file
# --> 591         config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     592         if config_dict is None:
#     593             return {}, kwargs
#
# /usr/local/lib/python3.11/dist-packages/transformers/configuration_utils.py in _get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     648             try:
#     649                 # Load from local folder or from cache or download from model Hub and cache
# --> 650                 resolved_config_file = cached_file(
#     651                     pretrained_model_name_or_path,
#     652                     configuration_file,
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     419         if resolved_file is not None or not _raise_exceptions_for_gated_repo:
#     420             return resolved_file
# --> 421         raise EnvironmentError(
#     422             "You are trying to access a gated repo.\nMake sure to have access to it at "
#     423             f"https://huggingface.co/{path_or_repo_id}.\n{str(e)}"
#
# OSError: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct.
# 401 Client Error. (Request ID: Root=1-67bef4e6-2cbf5d455f2e96c52ca9860f;2fe10bf5-d05e-49d5-9fc6-d8459a4f2d99)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-3.2-3B-Instruct/resolve/main/config.json.
# Access to model meta-llama/Llama-3.2-3B-Instruct is restricted. You must have access to it and be authenticated to access it. Please log in.

# %%
output_text, output_list, output_text_integrated = recursive_response_from_thinking(
    model=model,
    tokenizer=tokenizer,
    model_critic=critic_model,
    tokenizer_critic=tokenizer,  #same tokenizer for critic agent as the reasoning model in our case
    #question="Develop an idea of how graphene can be combined with silk fibers to create a filtration membrane.",
    question="How do biological materials fail gracefully?",
    N=3,
    temperature=0.1,
    temperature_improvement=0.1,
    system_prompt="You are a helpful assistant.",
    system_prompt_critic="You carefully improve responses, with attention to detail, and following all directions.",
    verbatim=False,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7bab9139d291> in <cell line: 0>()
#       2     model=model,
#       3     tokenizer=tokenizer,
# ----> 4     model_critic=critic_model,
#       5     tokenizer_critic=tokenizer,  #same tokenizer for critic agent as the reasoning model in our case
#       6     #question="Develop an idea of how graphene can be combined with silk fibers to create a filtration membrane.",
#
# NameError: name 'critic_model' is not defined

# %%
for i, item in enumerate(output_list):
    print (64*"-"+f"\n>>>i={i}<<<\n"+64*"-")
    print (item)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e4d519e22f7c> in <cell line: 0>()
# ----> 1 for i, item in enumerate(output_list):
#       2     print (64*"-"+f"\n>>>i={i}<<<\n"+64*"-")
#       3     print (item)
#
# NameError: name 'output_list' is not defined

# %%
print ("INTEGRATED RESPONSE:")
print (output_text_integrated)
# Out:
# INTEGRATED RESPONSE:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-7153356b87b5> in <cell line: 0>()
#       1 print ("INTEGRATED RESPONSE:")
# ----> 2 print (output_text_integrated)
#
# NameError: name 'output_text_integrated' is not defined
